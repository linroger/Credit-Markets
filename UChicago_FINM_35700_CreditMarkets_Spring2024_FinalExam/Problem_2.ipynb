# %% [markdown]
# # Credit Markets: Final Exam - Problem 2
#
# # FINM 35700 - Spring 2024
#
# ### UChicago Financial Mathematics
#
# ### May 7 2024 - from 6pm to 8:45pm
#
# * Alex Popovici
# * alex.popovici@uchicago.edu

# %% [markdown]
# Problem 2 relies on following symbology and market data files, as of 2024-05-03.
#
# - the bond symbology file `bond_symbology` and
# - the bond market data file `bond_market_prices_eod`.

# %% [markdown]
# ## Scoring: Total of 155 points
#
# | Problem | Points |
# |---------|--------|
# | 1: Overall understanding of credit models | 40     |
# | 2: **Risk and scenario analysis for a fixed rate corporate bond** | **20 <--**  |
# | 3: CDS calibration and pricing | 20     |
# | 4: Derivation of fixed rate bond PVs and DV01s in `sympy` | 25     |
# | 5: LQD ETF basket analysis - bucketed DV01 risks | 25     |
# | 6: Nelson-Siegel model for smooth hazard rates: ORCL curve | 25     |
# | Total   | 155    |
#
# ### Important:
# * You only need 100 points to reach 100% of the grade (out of 155 points in the problems)!
# * All functions used in previous homeworks are pre-loaded and ready to use, via credit_market_tools!
# * Please submit on time: late submissions (after 8:45pm) will be penalized at a rate of "1 point per minute"!

# %%
# import tools from previous homeworks
from credit_market_tools import *

# Use static calculation/valuation date of 2024-05-03, matching data available in the market prices EOD file
calc_date = ql.Date(3, 5, 2024)
ql.Settings.instance().evaluationDate = calc_date

# Calculation/valuation date as pd datetime
as_of_date = pd.to_datetime('2024-05-03')

# %% [markdown]
# -----------------------------------------------------------
# # Problem 2: Risk and scenario analysis for a fixed rate corporate bond (yield model) (20 points)
#
# ## Use Homework 3 Problem 1 as a template.

# %% [markdown]
# ## 2a. Create the AAPL fixed-rate corporate bond object (5 points)
# Load the bond symbology data and identify the following AAPL fixed rate bond:
# - security = 'AAPL 2.2 09/11/29' / isin = 'US037833AT77' / figi = 'BBG00Q5L6G53'
#
# Use the create_bond_from_symbology() function to create the corresponding AAPL bond object.
#
# List the bond cashflows using the get_bond_cashflows() function.

# %% [markdown]
# ## 2b. Compute the bond price, DV01, duration and convexity (analytic method). (5 points)
#
# Load the AAPL bond mid yield from the bond market data file, as of 2024-05-03.
#
# From the bond mid yield, compute the bond price, DV01, duration and convexity, using the analytic method.

# %% [markdown]
# ## c. Compute and plot scenario bond prices (5 points)
#
# Compute the scenario bond prices on the following scenario yield grid: [from 2% to 10% in steps of 0.5%]
#
# Plot the scenario prices (Y-axis) vs yieds (X-axis).

# %% [markdown]
# ## d. Compute and plot scenario bond durations and convexities (5 points)
#
# Compute the scenario bond durations and convexities on the scenario yield grid.
#
# Plot the scenario durations (Y-axis) vs yieds (X-axis).
#
# Plot the scenario convexities (Y-axis) vs yieds (X-axis).

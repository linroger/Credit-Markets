# %% [markdown]
# # Credit Markets: Final Exam - Problem 1
#
# # FINM 35700 - Spring 2024
#
# ### UChicago Financial Mathematics
#
# ### May 7 2024 - from 6pm to 8:45pm
#
# * Alex Popovici
# * alex.popovici@uchicago.edu

# %% [markdown]
# ## Scoring: Total of 155 points
#
# | Problem | Points |
# |---------|--------|
# | **1: Overall understanding of credit models** | **40 <--**   |
# | 2: Risk and scenario analysis for a fixed rate corporate bond | 20     |
# | 3: CDS calibration and pricing | 20     |
# | 4: Derivation of fixed rate bond PVs and DV01s in `sympy` | 25     |
# | 5: LQD ETF basket analysis - bucketed DV01 risks | 25     |
# | 6: Nelson-Siegel model for smooth hazard rates: ORCL curve | 25     |
# | Total   | 155    |
#
# ### Important:
# * You only need 100 points to reach 100% of the grade (out of 155 points in the problems)!
# * All functions used in previous homeworks are pre-loaded and ready to use, via credit_market_tools!
# * Please submit on time: late submissions (after 8:45pm) will be penalized at a rate of "1 point per minute"!

# %% [markdown]
# ------------------------------------------------------------------------------------------
# # Problem 1: Overall understanding of credit models (40 points)
# ## - When answering the individual questions, you should assume 'ceteris paribus' - all else being equal.
# ## - True or False answers are sufficient, no need for any explanation!

# %% [markdown]
# ## 1a. Fixed rate bond prices in the hazard rate model: True or False (10 points)
#
# ### For a better understanding of dependencies, you can use the fixed rate bond valuation formulas in the flat hazard rate model (formulas [54] and [55] in Lecture 3).
#
#
# 1. Fixed rate bond price is decreasing in interest rate
# 1. Fixed rate bond price is decreasing in hazard rate
# 1. Fixed rate bond price is decreasing in expected recovery rate
# 2. Fixed rate bond price is decreasing in coupon
# 3. Fixed rate bond price is decreasing in bond maturity

# %% [markdown]
# ## 1b. Fixed rate bond yields in the hazard rate model: True or False (10 points)
#
# 1. Fixed rate bond yield is decreasing in interest rate
# 1. Fixed rate bond yield is decreasing in hazard rate
# 1. Fixed rate bond yield is decreasing in expected recovery rate
# 2. Fixed rate bond yield is independent of the coupon
# 3. Fixed rate bond yield is decreasing in bond maturity

# %% [markdown]
# ## 1c. Equity and equity volatility in the Merton Structural Credit Model: True or False (10 points)
#
# ### - Think about the equity value as a "call option on assets with liabilities as strike" and use formulas [23] and [37] from Lecture 5
#
# 1. Equity value is decreasing with company assets
# 2. Equity volatility is decreasing with company assets
# 3. Equity value is decreasing with assets volatility
# 4. Equity value is decreasing with company liabilities
# 5. Equity volatility is decreasing with company liabilities

# %% [markdown]
# ## 1d. Yield and expected recovery rate in the Merton Structural Credit Model: True or False (10 points)
#
# 1. Yield is decreasing with company liabilities
# 2. Expected recovery rate is decreasing with company liabilities
# 3. Yield is decreasing with assets volatility
# 4. Credit spread is decreasing with asset values
# 5. Credit spread is decreasing with assets volatility
